# %% [markdown]
# <a href="https://www.kaggle.com/code/peacehegemony/spiral-dynamics-optimization-with-python?scriptVersionId=118692885" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Anaconda3-2020.02  Python 3.7.6  NumPy 1.19.5
# minimize Rosenbrock function n=3 using spiral optimization



import numpy as np



def rosenbrock_error(x, dim):
  # min val = 0.0 at [1,1,1, . . 1]
  dim = len(x)
  z = 0.0
  for i in range(dim-1):
    a = 100 * ((x[i+1] - x[i]**2)**2)
    b = (1 - x[i])**2
    z += a + b
  err = (z - 0.0)**2
  return err


def find_center(points, m):
  # center is point with smallest error
  # note: m = len(points) (number of points / solutions)
  n = len(points[0])  # n = dim
  best_err = rosenbrock_error(points[0], n)
  idx = 0
  for i in range(m):
    err = rosenbrock_error(points[i], n)
    if err < best_err:
      idx = i; best_err = err
  return np.copy(points[idx]) 


def move_point(x, R, RminusI, center):
  # move x vector to new position, spiraling around center
  # note: matmul() automatically promotes vector to matrix
  offset = np.matmul(RminusI, center)  # (3,3) x (3,) = (3,)
  new_x = np.matmul(R, x) - offset     # (3,3) x (3,) - (3,) = (3,)
  return new_x


def make_Rab(a, b, n, theta):
  # make Rotation matrix, dim = n, a, b are 1-based
  # helper for make_R() function 
  a -= 1; b -= 1  # convert a,b to 0-based
  result = np.zeros((n,n))
  for r in range(n):
    for c in range(n):
      if r == a and c == a: result[r][c] = np.cos(theta)
      elif r == a and c == b: result[r][c] = -np.sin(theta)
      elif r == b and c == a: result[r][c] = np.sin(theta)
      elif r == b and c == b: result[r][c] = np.cos(theta)
      elif r == c: result[r][c] = 1.0  # unfilled diagonal elements
  return result 


def make_R(n, theta):
  result = np.zeros((n,n))
  for i in range(n):
    for j in range(n):
      if i == j: result[i][j] = 1.0  # Identity
  for i in range(1,n):
    for j in range(1,i+1):
      print("making R " + str(n-i) + " " + str(n+1-j))
      R = make_Rab(n-i, n+1-j, n, theta)
      result = np.matmul(result, R)  # compose
  return result



def main():
  print("\nBegin spiral dynamics optimization demo ")
  print("Goal is to minimize Rosenbrock function in dim n=3")
  print("Function has known min = 0.0 at (1, 1, 1) ")


  # 0. prepare
  np.set_printoptions(precision=4, suppress=True, sign=" ")
  np.set_printoptions(formatter={'float': '{: 0.4f}'.format})
  np.random.seed(4)

  theta = np.pi/3  # radians. small = curved, large = squared
  r = 0.98  # closer to 1 = tight spiral, closer 0 = loose 
  m = 50    # number of points / possible solutions
  n = 3     # problem dimension
  max_iter = 1000

  print("\nSetting theta = %0.4f " % theta)
  print("Setting r = %0.2f " % r)
  print("Setting number of points m = %d " % m)
  print("Setting max_iter = %d " % max_iter)


  # 1. set up the Rotation matrix for n=3
  print("\nSetting up hard-coded spiral Rotation matrix R ")

  ct = np.cos(theta)
  st = np.sin(theta)
  R12 = np.array([[ct,  -st,    0],
                  [st,   ct,    0],
                  [0,     0,    1]])

  R13 = np.array([[ct,   0,   -st],
                  [0,    1,     0],
                  [st,   0,    ct]])

  R23 = np.array([[1,    0,     0],
                  [0,    ct,  -st],
                  [0,    st,   ct]])

  R = np.matmul(R23, np.matmul(R13, R12))  # compose
  # R = make_R(3, theta)  # programmatic approach

  R = r * R  # scale / shrink

  I3 = np.array([[1,0,0], [0,1,0], [0,0,1]])
  RminusI = R - I3


  # 2. create m initial points and 
  # find curr center (best point)
  print("\nCreating %d initial random points " % m)
  points = np.random.uniform(low=-5.0, high=5.0,
    size=(m, 3))

  center = find_center(points, m)
  print("\nInitial center (best) point: ")
  print(center)


  # 3. spiral points towards curr center, 
  # update center, repeat
  print("\nUsing spiral dynamics optimization: ")
  for itr in range(max_iter):
    if itr % 100 == 0:
      print("itr = %5d  curr center = " % itr, end="")
      print(center)
    for i in range(m):  # move each pt toward center
      x = points[i]
      points[i] = move_point(x, R, RminusI, center)
      # print(points); input()
    center = find_center(points, m)  # find new center


  # 4. show best center found 
    print("\nBest solution found: ")
    print(center)
    
    print("\nEnd spiral dynamics optimization demo ")

# %%
if __name__ == "__main__":
  main()
# Out:
# Begin spiral dynamics optimization demo
# Goal is to minimize Rosenbrock function in dim n=3
# Function has known min = 0.0 at (1, 1, 1)
#
# Setting theta = 1.0472
# Setting r = 0.98
# Setting number of points m = 50
# Setting max_iter = 1000
#
# Setting up hard-coded spiral Rotation matrix R
#
# Creating 50 initial random points
#
# Initial center (best) point:
# [-0.2738 -1.0722  1.1893]
#
# Using spiral dynamics optimization:
# itr =     0  curr center = [-0.2738 -1.0722  1.1893]
#
# Best solution found:
# [-0.2738 -1.0722  1.1893]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-1.4473  1.6816  2.2739]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-1.4473  1.6816  2.2739]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-1.4473  1.6816  2.2739]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.1776  1.4356  1.4002]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.6792 -0.1220  0.1499]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.6792 -0.1220  0.1499]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4906  0.5951  0.5350]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [-0.2115  0.0252 -0.0446]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.2603 -0.0055 -0.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.4870  0.2276  0.1396]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
# itr =   100  curr center = [ 0.7973  0.6681  0.4462]
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.7973  0.6681  0.4462]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0245  1.0944  1.1949]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0063  1.0409  1.1137]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0385  1.0879  1.1733]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0320  1.0552  1.1209]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0330  1.0751  1.1545]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 0.9977  0.9946  0.9993]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0061  1.0100  1.0296]
#
# End spiral dynamics optimization demo
# itr =   200  curr center = [ 1.0061  1.0100  1.0296]
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0136  1.0307  1.0566]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0106  1.0180  1.0391]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0009  1.0015  1.0070]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0043  1.0097  1.0227]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0042  1.0067  1.0114]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0042  1.0067  1.0114]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0042  1.0067  1.0114]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
# itr =   300  curr center = [ 1.0008  1.0010  1.0024]
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0010  1.0024]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0015  1.0031  1.0062]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0012  1.0024  1.0050]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0008  1.0013  1.0027]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
# itr =   400  curr center = [ 1.0004  1.0007  1.0016]
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0011  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0007  1.0014  1.0028]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0013  1.0026]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0006  1.0012  1.0023]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
# itr =   500  curr center = [ 1.0005  1.0011  1.0022]
#
# Best solution found:
# [ 1.0005  1.0011  1.0022]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0010  1.0021]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0010  1.0021]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0005  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0008  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0008  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0008  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0018]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0009  1.0017]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0008  1.0016]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0008  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0004  1.0007  1.0015]
#
# End spiral dynamics optimization demo
#
# ...
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
# itr =   900  curr center = [ 1.0003  1.0006  1.0012]
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
#
# Best solution found:
# [ 1.0003  1.0006  1.0012]
#
# End spiral dynamics optimization demo
